# %%
import numpy as np
import time

# %%
def python_version():
    t1 = time.time()
    X = range(100000000)
    Y = range(100000000)
    Z = []
    for i in range(100000000):
        Z.append(X[i] + Y[i])
    t2 = time.time()
    return t2 - t1

# %%
python_version()
# Out:
# 48.38299822807312

# %%
def numpy_version():
    t1 = time.time()
    X = np.arange(100000000)
    Y = np.arange(100000000)
    Z = X + Y
    t2 = time.time()
    return t2 - t1

# %%
numpy_version()
# Out:
# 1.3310048580169678
